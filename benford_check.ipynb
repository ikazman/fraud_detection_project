# %%
from data_observer import observer

# %%
observe = observer.Observer()

# %%
observe.check_benford()
# Out:
# Статистика Хи-Квадрат = 65.316533
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.
# --------------------------
# Статистика Хи-Квадрат = 28.971915
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.
# --------------------------
# Статистика Хи-Квадрат = 25.729820
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.
# --------------------------
# Статистика Хи-Квадрат = 63.047737
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.
# --------------------------
# Статистика Хи-Квадрат = 194.153169
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.
# --------------------------
# ...
