# %%
from data_observer import observer

# %%
observe = observer.Observer('data/spb_covid_info.csv')

# %%
observe.check_benford()
# Out:
# Статистика Хи-Квадрат = 98.221633
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.

# %%
observe = observer.Observer('data/moscow_covid_info.csv')

# %%
observe.check_benford()
# Out:
# Статистика Хи-Квадрат = 195.099933
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.

# %%
observe = observer.Observer('data/samara_covid_info.csv')

# %%
observe.check_benford()
# Out:
# Статистика Хи-Квадрат = 29.210050
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.

# %%
import pandas as pd

# %%
df = pd.read_csv('data/gb_covid_info.csv')

# %%
df.nunique()
# Out:
# DateTime          735
# Великобритания    689
# dtype: int64

# %%
observe = observer.Observer('data/gb_covid_info.csv')

# %%
observe.check_benford()
# Out:
# Статистика Хи-Квадрат = 62.221651
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.

# %%
observe = observer.Observer('data/usa_covid_info.csv')

# %%
observe.check_benford()
# Out:
# Статистика Хи-Квадрат = 20.072984
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.

# %%
observe = observer.Observer('data/australia_covid_info.csv')

# %%
observe.check_benford()
# Out:
# Статистика Хи-Квадрат = 62.950590
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.

# %%
observe = observer.Observer('data/south_korea_covid_info.csv')

# %%
observe.check_benford()
# Out:
# Статистика Хи-Квадрат = 64.350582
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.

# %%
observe = observer.Observer('data/belgium_covid_info.csv')

# %%
observe.check_benford()
# Out:
# Статистика Хи-Квадрат = 42.158662
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.

# %%
observe = observer.Observer('data/estonia_covid_info.csv')

# %%
observe.check_benford()
# Out:
# Статистика Хи-Квадрат = 27.596897
# Критическое значение статистики при p равном 0.05 - 15.51
# Реальное распределение не сооответствует теоретическому распределению.
